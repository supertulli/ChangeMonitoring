# %%
import os
from pyhealth.datasets import OMOPDataset
import pandas as pd

# %%
data_root_path = "./data/mimic-iv-demo-data-in-the-omop-common-data-model-0.9/1_omop_data_csv"
omop_table_list = [ f.rstrip('.csv') for f in os.listdir(data_root_path) if os.path.isfile(os.path.join(data_root_path,f))]

# %%
omop_table_list
# Out:
# ['condition_era',
#  'note_nlp',
#  'observation_period',
#  'provider',
#  'procedure_occurrence',
#  'care_site',
#  'cohort_definition',
#  '2b_vocabulary',
#  'specimen',
#  '2b_concept_relationship',
#  'drug_exposure',
#  'cdm_source',
#  'device_exposure',
#  'drug_era',
#  '2b_concept',
#  'metadata',
#  'dose_era',
#  'death',
#  'cost',
#  'note',
#  'visit_detail',
#  'location',
#  'observation',
#  'fact_relationship',
#  'payer_plan_period',
#  'person',
#  'condition_occurrence',
#  'cohort_attribute',
#  'attribute_definition',
#  'measurement',
#  'visit_occurrence',
#  'cohort']

# %%
omop_ds=OMOPDataset(
    root=data_root_path,
    tables=[],#["person","visit_occurrence","death"], # omop_table_list,
    code_mapping={}
)
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/pedro/anaconda3/envs/omop/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/pedro/anaconda3/envs/omop/lib/python3.11/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/pedro/anaconda3/envs/omop/lib/python3.11/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#              ^^^^^^^^^^^^^^^^^^^
# ...

# %%
  # read person table
person_df = pd.read_csv(
            os.path.join(data_root_path, "person.csv"),
            dtype={"person_id": str},
            nrows=None,
            # sep="\t",
        )

# %%
person_df
# Out:
#                person_id  gender_concept_id  year_of_birth  month_of_birth  \
# 0    3589912774911670296               8507           2095             NaN
# 1   -3210373572193940939               8507           2079             NaN
# 2    -775517641933593374               8507           2149             NaN
# 3   -2575767131279873665               8507           2050             NaN
# 4   -8970844422700220177               8507           2114             NaN
# ..                   ...                ...            ...             ...
# 95  -7671795861352464589               8532           2052             NaN
# 96   5734523979606454056               8532           2069             NaN
# 97   1532249960797525190               8532           2106             NaN
# 98   5894416985828315484               8532           2055             NaN
# 99  -3780452582396805474               8532           2058             NaN
#
# ...

# %%
        # read visit_occurrence table
visit_occurrence_df = pd.read_csv(
            os.path.join(data_root_path, "visit_occurrence.csv"),
            dtype={"person_id": str, "visit_occurrence_id": str},
        #     sep="\t",
        )
visit_occurrence_df
# Out:
#       visit_occurrence_id             person_id  visit_concept_id  \
# 0    -4406053801395356975   4783904755296699562          38004207
# 1     2636026522589494723  -6225647829918357531          38004207
# 2    -8900473297538187901   7918537411740862407          38004207
# 3    -8091470952174089624  -6225647829918357531          38004207
# 4     8144493519470334167   7155255168997124770          38004207
# ..                    ...                   ...               ...
# 847   6557338641781338493   4498126063475867818              8870
# 848  -9026896896997717305   4498126063475867818              8870
# 849   5538617222786573932   6128703162302148003            581385
# 850  -4177473998334219433  -3908355835367628651               262
# 851   3079807580745996118   3192038106523208432               262
#
#     visit_start_date visit_start_datetime visit_end_date   visit_end_datetime  \
# 0         2112-11-06  2112-11-06 11:05:00     2112-11-06  2112-11-06 11:05:00
# ...

# %%
        # read death table
death_df = pd.read_csv(
            os.path.join(self.root, "death.csv"),
            sep="\t",
            dtype={"person_id": str},
